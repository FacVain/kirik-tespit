# %%
#Naïve Bayes, Random Forest ve SVM modelleri eğiteceğiz.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score

from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
def process_line(line):
    features = [float(feature) for feature in line.strip().split()]
    return features

# %%
# VERİ İŞLENMESİ
with open("TibiaFrectured.txt", "r") as file1, open("TibiaNonfrectured.txt", "r") as file2:
    broken_bones_data = file1.readlines()
    intact_bones_data = file2.readlines()

# 1: Kırık kemik, 0: Kırık olmayan kemik
X = [process_line(line) for line in broken_bones_data + intact_bones_data]
y = [1] * len(broken_bones_data) + [0] * len(intact_bones_data) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=28)

# %%
#Random Forest

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)

predictions = rf_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print("Model Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

y_pred = predictions
print("DecisionTree results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# Model Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# DecisionTree results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00       411
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
# Confusion Matrix:
# <Axes: >

# %%
#SVM 

svm_classifier = SVC(kernel='rbf', C=10000)
svm_classifier.fit(X_train, y_train)

predictions = svm_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print("Model Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

y_pred = predictions
print("DecisionTree results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# Model Accuracy: 0.9953051643192489
# Precision: 0.9975669099756691
# Recall: 0.9975669099756691
# DecisionTree results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        15
#            1       1.00      1.00      1.00       411
#
#     accuracy                           1.00       426
#    macro avg       0.97      0.97      0.97       426
# weighted avg       1.00      1.00      1.00       426
#
# Confusion Matrix:
# <Axes: >

# %%
#Naïve Bayes

nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)

predictions = nb_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print("Model Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

y_pred = predictions
print("DecisionTree results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# Model Accuracy: 0.8309859154929577
# Precision: 1.0
# Recall: 0.8248175182481752
# DecisionTree results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.17      1.00      0.29        15
#            1       1.00      0.82      0.90       411
#
#     accuracy                           0.83       426
#    macro avg       0.59      0.91      0.60       426
# weighted avg       0.97      0.83      0.88       426
#
# Confusion Matrix:
# <Axes: >
