# %%
#Naïve Bayes, Random Forest ve SVM modelleri eğiteceğiz.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score

from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
def process_line(line):
    features = [float(feature) for feature in line.strip().split()]
    return features

# %%
# VERİ İŞLENMESİ
with open("frectured.txt", "r") as file1, open("nonFrectured.txt", "r") as file2:
    broken_bones_data = file1.readlines()
    intact_bones_data = file2.readlines()

# 1: Kırık kemik, 0: Kırık olmayan kemik
X = [process_line(line) for line in broken_bones_data + intact_bones_data]
y = [1] * len(broken_bones_data) + [0] * len(intact_bones_data) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=28)

# %%
#Random Forest

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)

predictions = rf_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print("Model Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

y_pred = predictions
print("DecisionTree results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# Model Accuracy: 0.847001223990208
# Precision: 0.717948717948718
# Recall: 0.19718309859154928
# DecisionTree results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91       675
#            1       0.72      0.20      0.31       142
#
#     accuracy                           0.85       817
#    macro avg       0.79      0.59      0.61       817
# weighted avg       0.83      0.85      0.81       817
#
# Confusion Matrix:
# <Axes: >

# %%
#SVM 

svm_classifier = SVC(kernel='rbf', C=10000)
svm_classifier.fit(X_train, y_train)

predictions = svm_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print("Model Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

y_pred = predictions
print("DecisionTree results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# Model Accuracy: 0.835985312117503
# Precision: 0.75
# Recall: 0.08450704225352113
# DecisionTree results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91       675
#            1       0.75      0.08      0.15       142
#
#     accuracy                           0.84       817
#    macro avg       0.79      0.54      0.53       817
# weighted avg       0.82      0.84      0.78       817
#
# Confusion Matrix:
# <Axes: >

# %%
#Naïve Bayes

nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)

predictions = nb_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print("Model Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

y_pred = predictions
print("DecisionTree results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# Model Accuracy: 0.7490820073439413
# Precision: 0.2733812949640288
# Recall: 0.2676056338028169
# DecisionTree results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       675
#            1       0.27      0.27      0.27       142
#
#     accuracy                           0.75       817
#    macro avg       0.56      0.56      0.56       817
# weighted avg       0.75      0.75      0.75       817
#
# Confusion Matrix:
# <Axes: >
