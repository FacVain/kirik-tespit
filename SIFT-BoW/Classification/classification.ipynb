# %%
import pandas as pd
import seaborn as sns
from sklearn import svm
from numpy import mean
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold, cross_val_score

# %%
train = pd.read_csv('../SIFTextraction/train.csv')
test = pd.read_csv('../SIFTextraction/test.csv')
train
# Out:
#             image_id  hand  leg  hip  shoulder  mixed  label         0  \
# 0     IMG0000375.jpg     0    1    0         0      0      0 -0.242657
# 1     IMG0003873.jpg     1    0    0         1      1      0 -0.242657
# 2     IMG0002796.jpg     0    1    0         0      0      0 -0.242657
# 3     IMG0003700.jpg     1    0    0         0      0      0 -0.242657
# 4     IMG0003388.jpg     0    1    0         0      0      0 -0.242657
# ...              ...   ...  ...  ...       ...    ...    ...       ...
# 3261  IMG0001188.jpg     0    1    0         0      0      0 -0.242657
# 3262  IMG0001452.jpg     0    1    0         0      0      0 -0.242657
# 3263  IMG0001181.jpg     0    1    0         0      0      0 -0.242657
# 3264  IMG0001696.jpg     0    0    1         0      0      0 -0.242657
# 3265  IMG0000472.jpg     0    1    0         0      0      1 -0.242657
#
#              1         2  ...       190       191       192       193  \
# 0    -0.211284 -0.325812  ... -0.206691 -0.248059 -0.045642 -0.209752
# 1    -0.211284 -0.161014  ... -0.206691 -0.033561 -0.045642 -0.209752
# 2    -0.211284 -0.325812  ... -0.206691  0.180938 -0.252104 -0.209752
# 3    -0.211284 -0.161014  ... -0.094276 -0.248059 -0.252104 -0.209752
# 4    -0.211284  0.003784  ... -0.094276 -0.033561 -0.252104 -0.209752
# ...        ...       ...  ...       ...       ...       ...       ...
# 3261 -0.211284 -0.325812  ... -0.206691 -0.248059 -0.252104 -0.209752
# 3262 -0.211284 -0.161014  ... -0.206691 -0.248059 -0.252104 -0.209752
# 3263 -0.211284 -0.325812  ... -0.206691 -0.248059 -0.252104 -0.209752
# 3264  0.088609  0.168583  ... -0.206691 -0.033561 -0.252104 -0.209752
# 3265 -0.211284  0.003784  ... -0.206691 -0.248059 -0.252104 -0.209752
#
#            194       195      196       197       198       199
# 0    -0.266092 -0.301074 -0.22646 -0.213012 -0.251152 -0.246858
# 1    -0.266092 -0.301074 -0.22646 -0.213012 -0.090127 -0.246858
# 2    -0.266092 -0.301074 -0.22646 -0.213012 -0.251152  0.017050
# 3    -0.266092 -0.301074 -0.22646 -0.213012 -0.251152 -0.246858
# 4     0.043732 -0.301074 -0.22646 -0.213012 -0.090127 -0.246858
# ...        ...       ...      ...       ...       ...       ...
# 3261 -0.266092 -0.301074 -0.22646 -0.213012 -0.251152 -0.246858
# 3262  0.043732 -0.301074 -0.22646 -0.213012 -0.251152  0.017050
# 3263 -0.266092 -0.301074 -0.22646 -0.036574 -0.251152 -0.246858
# 3264  0.043732  0.029783 -0.22646 -0.213012 -0.251152 -0.246858
# 3265 -0.266092 -0.301074 -0.22646 -0.213012 -0.090127 -0.246858
#
# [3266 rows x 207 columns]

# %%
X_train = train.drop(columns=['image_id', 'label'])
y_train = train['label']

X_test = test.drop(columns=['image_id', 'label'])
y_test = test['label']


model = svm.SVC(gamma='scale')

param_grid = {
    'class_weight': ({0:1, 1:2}, {0:1,1:4}, {0:1,1:5}),
    'kernel': ('rbf', 'sigmoid'),
    'C': (2, 3),
    'degree': (2, 3)
}
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='f1')

grid_result = grid.fit(X_train, y_train)

# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.476774 using {'C': 3, 'class_weight': {0: 1, 1: 4}, 'degree': 2, 'kernel': 'rbf'}
# 0.357335 (0.067119) with: {'C': 2, 'class_weight': {0: 1, 1: 2}, 'degree': 2, 'kernel': 'rbf'}
# 0.357703 (0.046337) with: {'C': 2, 'class_weight': {0: 1, 1: 2}, 'degree': 2, 'kernel': 'sigmoid'}
# 0.357335 (0.067119) with: {'C': 2, 'class_weight': {0: 1, 1: 2}, 'degree': 3, 'kernel': 'rbf'}
# 0.357703 (0.046337) with: {'C': 2, 'class_weight': {0: 1, 1: 2}, 'degree': 3, 'kernel': 'sigmoid'}
# 0.470710 (0.049759) with: {'C': 2, 'class_weight': {0: 1, 1: 4}, 'degree': 2, 'kernel': 'rbf'}
# 0.341994 (0.036009) with: {'C': 2, 'class_weight': {0: 1, 1: 4}, 'degree': 2, 'kernel': 'sigmoid'}
# 0.470710 (0.049759) with: {'C': 2, 'class_weight': {0: 1, 1: 4}, 'degree': 3, 'kernel': 'rbf'}
# 0.341994 (0.036009) with: {'C': 2, 'class_weight': {0: 1, 1: 4}, 'degree': 3, 'kernel': 'sigmoid'}
# 0.438872 (0.033821) with: {'C': 2, 'class_weight': {0: 1, 1: 5}, 'degree': 2, 'kernel': 'rbf'}
# 0.340076 (0.032868) with: {'C': 2, 'class_weight': {0: 1, 1: 5}, 'degree': 2, 'kernel': 'sigmoid'}
# 0.438872 (0.033821) with: {'C': 2, 'class_weight': {0: 1, 1: 5}, 'degree': 3, 'kernel': 'rbf'}
# 0.340076 (0.032868) with: {'C': 2, 'class_weight': {0: 1, 1: 5}, 'degree': 3, 'kernel': 'sigmoid'}
# 0.379578 (0.064193) with: {'C': 3, 'class_weight': {0: 1, 1: 2}, 'degree': 2, 'kernel': 'rbf'}
# 0.355358 (0.047132) with: {'C': 3, 'class_weight': {0: 1, 1: 2}, 'degree': 2, 'kernel': 'sigmoid'}
# 0.379578 (0.064193) with: {'C': 3, 'class_weight': {0: 1, 1: 2}, 'degree': 3, 'kernel': 'rbf'}
# 0.355358 (0.047132) with: {'C': 3, 'class_weight': {0: 1, 1: 2}, 'degree': 3, 'kernel': 'sigmoid'}
# 0.476774 (0.047901) with: {'C': 3, 'class_weight': {0: 1, 1: 4}, 'degree': 2, 'kernel': 'rbf'}
# 0.342994 (0.035987) with: {'C': 3, 'class_weight': {0: 1, 1: 4}, 'degree': 2, 'kernel': 'sigmoid'}
# 0.476774 (0.047901) with: {'C': 3, 'class_weight': {0: 1, 1: 4}, 'degree': 3, 'kernel': 'rbf'}
# 0.342994 (0.035987) with: {'C': 3, 'class_weight': {0: 1, 1: 4}, 'degree': 3, 'kernel': 'sigmoid'}
# 0.445825 (0.036279) with: {'C': 3, 'class_weight': {0: 1, 1: 5}, 'degree': 2, 'kernel': 'rbf'}
# 0.340701 (0.032484) with: {'C': 3, 'class_weight': {0: 1, 1: 5}, 'degree': 2, 'kernel': 'sigmoid'}
# 0.445825 (0.036279) with: {'C': 3, 'class_weight': {0: 1, 1: 5}, 'degree': 3, 'kernel': 'rbf'}
# 0.340701 (0.032484) with: {'C': 3, 'class_weight': {0: 1, 1: 5}, 'degree': 3, 'kernel': 'sigmoid'}

# %%
weigths = grid_result.best_params_['class_weight']
model = svm.SVC(gamma='scale', class_weight=weigths)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.82       674
#            1       0.30      0.48      0.37       143
#
#     accuracy                           0.71       817
#    macro avg       0.59      0.62      0.59       817
# weighted avg       0.77      0.71      0.74       817
#
# Confusion Matrix:
# <Axes: >

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
from sklearn.metrics import classification_report

# Define the model architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'AUC', 'Precision', 'Recall'])
callback = EarlyStopping(monitor='AUC', patience=3)
# Fit the model to the training data
model.fit(np.asarray(X_train).astype('float32'), np.asarray(y_train).astype('float32'), epochs=50, batch_size=64, class_weight={0: 1, 1: 6}, callbacks=[callback])
# Out:
# Epoch 1/50
# 47/52 [==========================>...] - ETA: 0s - loss: 1.2157 - accuracy: 0.6486 - auc: 0.7070 - precision: 0.2918 - recall: 0.6994WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2091 - accuracy: 0.6372 - auc: 0.7068 - precision: 0.2862 - recall: 0.7125
# Epoch 2/50
# 49/52 [===========================>..] - ETA: 0s - loss: 1.0715 - accuracy: 0.6543 - auc: 0.7702 - precision: 0.3024 - recall: 0.7482WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 9ms/step - loss: 1.0688 - accuracy: 0.6574 - auc: 0.7726 - precision: 0.3055 - recall: 0.7456
# Epoch 3/50
# 50/52 [===========================>..] - ETA: 0s - loss: 1.0014 - accuracy: 0.6978 - auc: 0.8009 - precision: 0.3409 - recall: 0.7722WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.9980 - accuracy: 0.6993 - auc: 0.8030 - precision: 0.3428 - recall: 0.7753
# Epoch 4/50
# 52/52 [==============================] - ETA: 0s - loss: 1.0030 - accuracy: 0.7002 - auc: 0.8004 - precision: 0.3409 - recall: 0.7561WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0030 - accuracy: 0.7002 - auc: 0.8004 - precision: 0.3409 - recall: 0.7561
# Epoch 5/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.9598 - accuracy: 0.7210 - auc: 0.8204 - precision: 0.3645 - recall: 0.7945WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 6ms/step - loss: 0.9565 - accuracy: 0.7189 - auc: 0.8223 - precision: 0.3637 - recall: 0.7997
# Epoch 6/50
# 52/52 [==============================] - ETA: 0s - loss: 0.9204 - accuracy: 0.7428 - auc: 0.8386 - precision: 0.3859 - recall: 0.7840WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 6ms/step - loss: 0.9204 - accuracy: 0.7428 - auc: 0.8386 - precision: 0.3859 - recall: 0.7840
# Epoch 7/50
# 48/52 [==========================>...] - ETA: 0s - loss: 0.8874 - accuracy: 0.7594 - auc: 0.8484 - precision: 0.4002 - recall: 0.7958WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.8945 - accuracy: 0.7581 - auc: 0.8484 - precision: 0.4046 - recall: 0.7979
# Epoch 8/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.8708 - accuracy: 0.7484 - auc: 0.8574 - precision: 0.3981 - recall: 0.8183WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.8672 - accuracy: 0.7517 - auc: 0.8581 - precision: 0.3991 - recall: 0.8171
# Epoch 9/50
# 47/52 [==========================>...] - ETA: 0s - loss: 0.8644 - accuracy: 0.7543 - auc: 0.8618 - precision: 0.4020 - recall: 0.8254WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.8584 - accuracy: 0.7551 - auc: 0.8645 - precision: 0.4039 - recall: 0.8275
# Epoch 10/50
# 44/52 [========================>.....] - ETA: 0s - loss: 0.8373 - accuracy: 0.7717 - auc: 0.8707 - precision: 0.4249 - recall: 0.8233WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 6ms/step - loss: 0.8392 - accuracy: 0.7716 - auc: 0.8694 - precision: 0.4232 - recall: 0.8258
# Epoch 11/50
# 52/52 [==============================] - ETA: 0s - loss: 0.8745 - accuracy: 0.7419 - auc: 0.8560 - precision: 0.3895 - recall: 0.8258WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 6ms/step - loss: 0.8745 - accuracy: 0.7419 - auc: 0.8560 - precision: 0.3895 - recall: 0.8258
# Epoch 12/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.8095 - accuracy: 0.7828 - auc: 0.8792 - precision: 0.4353 - recall: 0.8245WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.8166 - accuracy: 0.7811 - auc: 0.8777 - precision: 0.4350 - recall: 0.8223
# Epoch 13/50
# 48/52 [==========================>...] - ETA: 0s - loss: 0.7697 - accuracy: 0.7835 - auc: 0.8908 - precision: 0.4369 - recall: 0.8411WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.7888 - accuracy: 0.7826 - auc: 0.8853 - precision: 0.4376 - recall: 0.8310
# Epoch 14/50
# 52/52 [==============================] - ETA: 0s - loss: 0.7794 - accuracy: 0.7961 - auc: 0.8890 - precision: 0.4559 - recall: 0.8293WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 1s 10ms/step - loss: 0.7794 - accuracy: 0.7961 - auc: 0.8890 - precision: 0.4559 - recall: 0.8293
# Epoch 15/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.8005 - accuracy: 0.7870 - auc: 0.8837 - precision: 0.4471 - recall: 0.8143WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.7961 - accuracy: 0.7860 - auc: 0.8834 - precision: 0.4412 - recall: 0.8171
# Epoch 16/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.7339 - accuracy: 0.8172 - auc: 0.9028 - precision: 0.4882 - recall: 0.8470WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.7303 - accuracy: 0.8181 - auc: 0.9040 - precision: 0.4899 - recall: 0.8484
# Epoch 17/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.6898 - accuracy: 0.8181 - auc: 0.9152 - precision: 0.4905 - recall: 0.8739WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.6910 - accuracy: 0.8190 - auc: 0.9148 - precision: 0.4916 - recall: 0.8711
# Epoch 18/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.7340 - accuracy: 0.8013 - auc: 0.9023 - precision: 0.4644 - recall: 0.8530WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.7238 - accuracy: 0.8059 - auc: 0.9053 - precision: 0.4712 - recall: 0.8554
# Epoch 19/50
# 48/52 [==========================>...] - ETA: 0s - loss: 0.6599 - accuracy: 0.8298 - auc: 0.9226 - precision: 0.5116 - recall: 0.8881WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.6623 - accuracy: 0.8291 - auc: 0.9214 - precision: 0.5080 - recall: 0.8815
# Epoch 20/50
# 47/52 [==========================>...] - ETA: 0s - loss: 0.6624 - accuracy: 0.8314 - auc: 0.9213 - precision: 0.5138 - recall: 0.8722WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 9ms/step - loss: 0.6700 - accuracy: 0.8313 - auc: 0.9191 - precision: 0.5119 - recall: 0.8641
# Epoch 21/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.7132 - accuracy: 0.8166 - auc: 0.9088 - precision: 0.4884 - recall: 0.8768WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.7150 - accuracy: 0.8166 - auc: 0.9082 - precision: 0.4878 - recall: 0.8711
# Epoch 22/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.6261 - accuracy: 0.8469 - auc: 0.9325 - precision: 0.5447 - recall: 0.8988WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.6271 - accuracy: 0.8423 - auc: 0.9311 - precision: 0.5303 - recall: 0.8990
# Epoch 23/50
# 46/52 [=========================>....] - ETA: 0s - loss: 0.5909 - accuracy: 0.8543 - auc: 0.9387 - precision: 0.5565 - recall: 0.8931WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.6044 - accuracy: 0.8576 - auc: 0.9351 - precision: 0.5608 - recall: 0.8763
# Epoch 24/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.5839 - accuracy: 0.8406 - auc: 0.9397 - precision: 0.5266 - recall: 0.8984WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5830 - accuracy: 0.8402 - auc: 0.9400 - precision: 0.5265 - recall: 0.8990
# Epoch 25/50
# 48/52 [==========================>...] - ETA: 0s - loss: 0.5746 - accuracy: 0.8490 - auc: 0.9414 - precision: 0.5420 - recall: 0.8980WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5654 - accuracy: 0.8500 - auc: 0.9436 - precision: 0.5440 - recall: 0.9042
# Epoch 26/50
# 52/52 [==============================] - ETA: 0s - loss: 0.5344 - accuracy: 0.8625 - auc: 0.9489 - precision: 0.5682 - recall: 0.9077WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5344 - accuracy: 0.8625 - auc: 0.9489 - precision: 0.5682 - recall: 0.9077
# Epoch 27/50
# 51/52 [============================>.] - ETA: 0s - loss: 0.5294 - accuracy: 0.8594 - auc: 0.9507 - precision: 0.5625 - recall: 0.8953WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5306 - accuracy: 0.8592 - auc: 0.9505 - precision: 0.5625 - recall: 0.8937
# Epoch 28/50
# 48/52 [==========================>...] - ETA: 0s - loss: 0.8589 - accuracy: 0.7624 - auc: 0.8755 - precision: 0.4111 - recall: 0.8305WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.8474 - accuracy: 0.7664 - auc: 0.8784 - precision: 0.4176 - recall: 0.8345
# Epoch 29/50
# 52/52 [==============================] - ETA: 0s - loss: 0.5967 - accuracy: 0.8466 - auc: 0.9370 - precision: 0.5387 - recall: 0.8850WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.5967 - accuracy: 0.8466 - auc: 0.9370 - precision: 0.5387 - recall: 0.8850
# Epoch 30/50
# 45/52 [========================>.....] - ETA: 0s - loss: 0.5078 - accuracy: 0.8747 - auc: 0.9546 - precision: 0.5917 - recall: 0.9105WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.5175 - accuracy: 0.8760 - auc: 0.9529 - precision: 0.5972 - recall: 0.9042
# Epoch 31/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.5496 - accuracy: 0.8600 - auc: 0.9463 - precision: 0.5607 - recall: 0.9104WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5474 - accuracy: 0.8604 - auc: 0.9471 - precision: 0.5636 - recall: 0.9111
# Epoch 32/50
# 45/52 [========================>.....] - ETA: 0s - loss: 0.4457 - accuracy: 0.8972 - auc: 0.9649 - precision: 0.6448 - recall: 0.9187WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4546 - accuracy: 0.8925 - auc: 0.9636 - precision: 0.6345 - recall: 0.9164
# Epoch 33/50
# 47/52 [==========================>...] - ETA: 0s - loss: 0.7679 - accuracy: 0.7716 - auc: 0.8943 - precision: 0.4313 - recall: 0.8466WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.7488 - accuracy: 0.7771 - auc: 0.8980 - precision: 0.4317 - recall: 0.8484
# Epoch 34/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.5566 - accuracy: 0.8478 - auc: 0.9443 - precision: 0.5391 - recall: 0.8982WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.5548 - accuracy: 0.8484 - auc: 0.9448 - precision: 0.5414 - recall: 0.8990
# Epoch 35/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.4657 - accuracy: 0.8715 - auc: 0.9621 - precision: 0.5879 - recall: 0.9246WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.4633 - accuracy: 0.8723 - auc: 0.9622 - precision: 0.5865 - recall: 0.9268
# Epoch 36/50
# 51/52 [============================>.] - ETA: 0s - loss: 0.5917 - accuracy: 0.8361 - auc: 0.9371 - precision: 0.5193 - recall: 0.8901WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.5915 - accuracy: 0.8362 - auc: 0.9372 - precision: 0.5198 - recall: 0.8902
# Epoch 37/50
# 46/52 [=========================>....] - ETA: 0s - loss: 0.5057 - accuracy: 0.8665 - auc: 0.9536 - precision: 0.5742 - recall: 0.9284WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 1s 10ms/step - loss: 0.4929 - accuracy: 0.8696 - auc: 0.9562 - precision: 0.5806 - recall: 0.9286
# Epoch 38/50
# 51/52 [============================>.] - ETA: 0s - loss: 0.4965 - accuracy: 0.8817 - auc: 0.9563 - precision: 0.6076 - recall: 0.9251WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.4962 - accuracy: 0.8818 - auc: 0.9564 - precision: 0.6076 - recall: 0.9251
# Epoch 39/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.4133 - accuracy: 0.8875 - auc: 0.9700 - precision: 0.6174 - recall: 0.9448WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.4146 - accuracy: 0.8876 - auc: 0.9699 - precision: 0.6180 - recall: 0.9443
# Epoch 40/50
# 48/52 [==========================>...] - ETA: 0s - loss: 0.3967 - accuracy: 0.8945 - auc: 0.9723 - precision: 0.6363 - recall: 0.9391WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3936 - accuracy: 0.8968 - auc: 0.9727 - precision: 0.6409 - recall: 0.9390
# Epoch 41/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3501 - accuracy: 0.9081 - auc: 0.9782 - precision: 0.6683 - recall: 0.9485WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3454 - accuracy: 0.9097 - auc: 0.9788 - precision: 0.6720 - recall: 0.9495
# Epoch 42/50
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3450 - accuracy: 0.9122 - auc: 0.9790 - precision: 0.6816 - recall: 0.9415WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3415 - accuracy: 0.9137 - auc: 0.9794 - precision: 0.6848 - recall: 0.9425
# Epoch 43/50
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3579 - accuracy: 0.9123 - auc: 0.9767 - precision: 0.6768 - recall: 0.9448WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3535 - accuracy: 0.9112 - auc: 0.9777 - precision: 0.6766 - recall: 0.9477
# Epoch 44/50
# 47/52 [==========================>...] - ETA: 0s - loss: 0.3495 - accuracy: 0.9096 - auc: 0.9786 - precision: 0.6747 - recall: 0.9456WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3453 - accuracy: 0.9097 - auc: 0.9788 - precision: 0.6724 - recall: 0.9477
# Epoch 45/50
# 45/52 [========================>.....] - ETA: 0s - loss: 0.3381 - accuracy: 0.9083 - auc: 0.9789 - precision: 0.6685 - recall: 0.9465WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3370 - accuracy: 0.9094 - auc: 0.9790 - precision: 0.6725 - recall: 0.9443
# Epoch 46/50
# 46/52 [=========================>....] - ETA: 0s - loss: 0.3302 - accuracy: 0.9096 - auc: 0.9801 - precision: 0.6717 - recall: 0.9497WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3302 - accuracy: 0.9094 - auc: 0.9799 - precision: 0.6712 - recall: 0.9495
# Epoch 47/50
# 52/52 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.9170 - auc: 0.9831 - precision: 0.6896 - recall: 0.9599WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.3058 - accuracy: 0.9170 - auc: 0.9831 - precision: 0.6896 - recall: 0.9599
# Epoch 48/50
# 47/52 [==========================>...] - ETA: 0s - loss: 0.2873 - accuracy: 0.9212 - auc: 0.9848 - precision: 0.7052 - recall: 0.9629WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 10ms/step - loss: 0.2845 - accuracy: 0.9213 - auc: 0.9849 - precision: 0.7014 - recall: 0.9617
# Epoch 49/50
# 48/52 [==========================>...] - ETA: 0s - loss: 0.2376 - accuracy: 0.9362 - auc: 0.9900 - precision: 0.7464 - recall: 0.9608WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.2431 - accuracy: 0.9317 - auc: 0.9897 - precision: 0.7325 - recall: 0.9634
# Epoch 50/50
# 51/52 [============================>.] - ETA: 0s - loss: 0.3617 - accuracy: 0.9044 - auc: 0.9763 - precision: 0.6582 - recall: 0.9476WARNING:tensorflow:Early stopping conditioned on metric `AUC` which is not available. Available metrics are: loss,accuracy,auc,precision,recall
# 52/52 [==============================] - 0s 8ms/step - loss: 0.3615 - accuracy: 0.9045 - auc: 0.9763 - precision: 0.6586 - recall: 0.9477

# %%
# Predict on the test data
y_pred = model.predict(np.asarray(X_test).astype('float32'))

# Convert predictions to binary labels
y_pred_binary = np.round(y_pred)

# Generate classification report
report = classification_report(np.asarray(y_test).astype('float32'), y_pred_binary)
print("Classification Report:")
print(report)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.80      0.85       674
#          1.0       0.40      0.62      0.49       143
#
#     accuracy                           0.77       817
#    macro avg       0.66      0.71      0.67       817
# weighted avg       0.82      0.77      0.79       817

# %%
sns.heatmap(confusion_matrix(y_test,y_pred_binary),annot = True,fmt='d')
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeClassifier

param_grid = {
    'criterion': ('gini', 'entropy'),
    'splitter': ('best', 'random'),
    'max_depth': (None, 10, 20, 30)
}
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
model = DecisionTreeClassifier()
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='f1')

grid_result = grid.fit(X_train, y_train)

print("Best: %f using %s" % (grid_result.best_score_ , grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.416093 using {'criterion': 'gini', 'max_depth': 20, 'splitter': 'random'}
# 0.403606 (0.041423) with: {'criterion': 'gini', 'max_depth': None, 'splitter': 'best'}
# 0.395375 (0.060384) with: {'criterion': 'gini', 'max_depth': None, 'splitter': 'random'}
# 0.395908 (0.060806) with: {'criterion': 'gini', 'max_depth': 10, 'splitter': 'best'}
# 0.374023 (0.063107) with: {'criterion': 'gini', 'max_depth': 10, 'splitter': 'random'}
# 0.399661 (0.052826) with: {'criterion': 'gini', 'max_depth': 20, 'splitter': 'best'}
# 0.416093 (0.065394) with: {'criterion': 'gini', 'max_depth': 20, 'splitter': 'random'}
# 0.401839 (0.048439) with: {'criterion': 'gini', 'max_depth': 30, 'splitter': 'best'}
# 0.385687 (0.055354) with: {'criterion': 'gini', 'max_depth': 30, 'splitter': 'random'}
# 0.397846 (0.060819) with: {'criterion': 'entropy', 'max_depth': None, 'splitter': 'best'}
# 0.396203 (0.062406) with: {'criterion': 'entropy', 'max_depth': None, 'splitter': 'random'}
# 0.389707 (0.055149) with: {'criterion': 'entropy', 'max_depth': 10, 'splitter': 'best'}
# 0.377084 (0.063023) with: {'criterion': 'entropy', 'max_depth': 10, 'splitter': 'random'}
# 0.391212 (0.057567) with: {'criterion': 'entropy', 'max_depth': 20, 'splitter': 'best'}
# 0.379789 (0.062992) with: {'criterion': 'entropy', 'max_depth': 20, 'splitter': 'random'}
# 0.398781 (0.063474) with: {'criterion': 'entropy', 'max_depth': 30, 'splitter': 'best'}
# 0.385578 (0.047504) with: {'criterion': 'entropy', 'max_depth': 30, 'splitter': 'random'}

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=None, splitter='random')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred_binary),annot = True,fmt='d')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       674
#            1       0.38      0.39      0.38       143
#
#     accuracy                           0.78       817
#    macro avg       0.62      0.63      0.62       817
# weighted avg       0.78      0.78      0.78       817
#
# Confusion Matrix:
# <Axes: >
