# %%
import pickle
import pandas as pd
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns
# Out:
# C:\Users\assas\AppData\Local\Temp\ipykernel_16544\1201726988.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
test = pd.read_csv('../../SIFTextraction/fracatlas/test.csv')

X_test = test.drop(columns=['image_id', 'label'])
y_test = test['label']

# %%
svc = pickle.load(open('./models/svc.pkl', 'rb'))
dt = pickle.load(open('./models/dt.pkl', 'rb'))

# %%
y_pred = svc.predict(X_test)
print("SVM results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# SVM results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       674
#            1       0.36      0.45      0.40       143
#
#     accuracy                           0.76       817
#    macro avg       0.62      0.64      0.62       817
# weighted avg       0.78      0.76      0.77       817
#
# Confusion Matrix:
# <Axes: >

# %%
y_pred = dt.predict(X_test)
print("DecisionTree results:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred),annot = True,fmt='d')
# Out:
# DecisionTree results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       674
#            1       0.40      0.45      0.42       143
#
#     accuracy                           0.79       817
#    macro avg       0.64      0.65      0.65       817
# weighted avg       0.80      0.79      0.79       817
#
# Confusion Matrix:
# <Axes: >

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_test.shape[1]))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'AUC', 'Precision', 'Recall'])

model.load_weights('./models/nn.h5')

# %%
y_pred = model.predict(np.asarray(X_test).astype('float32'))
y_pred_binary = np.round(y_pred)

print("MLP results:")
print("Classification Report:")
print(classification_report(y_test, y_pred_binary))
print("Confusion Matrix:")
sns.heatmap(confusion_matrix(y_test,y_pred_binary),annot = True,fmt='d')
# Out:
# 26/26 [==============================] - 2s 1ms/step
# MLP results:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       674
#            1       0.46      0.52      0.49       143
#
#     accuracy                           0.81       817
#    macro avg       0.68      0.69      0.68       817
# weighted avg       0.82      0.81      0.81       817
#
# Confusion Matrix:
# <Axes: >

# %%
correct_predictions = (np.reshape(y_test, (817, 1)) == 1) & (y_pred_binary == 1)
correct_sample = test[correct_predictions].sample(n=1)

wrong_predictions = (np.reshape(y_test, (817, 1)) == 1) & (y_pred_binary == 0)
wrong_sample = test[wrong_predictions].sample(n=1)

correct_sample = correct_sample.iloc[0]
wrong_sample = wrong_sample.iloc[0]

print("Randomly selected correct prediction of label 1:")
print(correct_sample)

print("\nRandomly selected wrong prediction where model predicted 0 but label is 1:")
print(wrong_sample)
# Out:
# Randomly selected correct prediction of label 1:
# image_id    IMG0003509.jpg
# hand                     1
# leg                      0
# hip                      0
# shoulder                 0
#                  ...
# 195              -0.301074
# 196               -0.22646
# 197              -0.213012
# 198              -0.251152
# 199              -0.246858
# Name: 358, Length: 207, dtype: object
#
# Randomly selected wrong prediction where model predicted 0 but label is 1:
# image_id    IMG0002435.jpg
# hand                     0
# leg                      1
# hip                      0
# shoulder                 0
#                  ...
# 195              -0.301074
# 196               -0.22646
# 197              -0.213012
# 198              -0.251152
# 199              -0.246858
# Name: 585, Length: 207, dtype: object

# %%
import cv2 as cv
from matplotlib import pyplot as plt

img1 = cv.imread('../../../data/FracAtlas/images/Fractured/IMG0003509.jpg')
img2 = cv.imread('../../../data/FracAtlas/images/Fractured/IMG0002435.jpg')

plt.subplot(121),plt.imshow(img1,cmap = 'gray')
plt.title('Correctly classified as Fractured'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img2,cmap = 'gray')
plt.title('Cannot classified as Fractured'), plt.xticks([]), plt.yticks([])
plt.show()
